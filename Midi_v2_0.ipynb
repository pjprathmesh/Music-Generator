# %% [markdown]
# <a href="https://colab.research.google.com/github/pjprathmesh/Music-Generator/blob/master/Midi_v2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://storage.googleapis.com/magentadata/datasets/maestro/v2.0.0/maestro-v2.0.0-midi.zip
# !unzip /content/maestro-v2.0.0-midi.zip

# %%
# !pip install pretty_midi

# %%
import pretty_midi
import numpy as np
import os
from keras.layers import LSTM,Input,Dense,Dropout
from keras.models import Model
from keras.callbacks import LambdaCallback
from keras.utils   import to_categorical
def create():
    max_T_x = 1000
    l1=os.listdir("/content/maestro-v2.0.0")
    l2=[i for i in l1 if i.isnumeric() ]
    l3=[os.listdir(os.path.join("/content/maestro-v2.0.0",j)) for j in l2]

    mapp=[i for i in range(109)]
    char2vec={e:i for e,i in enumerate(mapp)}
    vec2char={i:e for e,i in enumerate(mapp)}

    ma=0
    final=np.zeros((9900,20,110))
    pre=np.zeros((9900,20,110))
    for e,i in enumerate(l3):
        if e==1:
            break

        for h,j in enumerate(i):
            if h==10:
              break
              
            midi_pretty_format = pretty_midi.PrettyMIDI(os.path.join("/content/maestro-v2.0.0",l2[e],j))
            note_l = [note.pitch for note in midi_pretty_format.instruments[0].notes][:2000]
            for k in range(0,len(note_l)-20,3):
                final_vt=note_l[k:k+20]
                pred=final_vt.copy()
                del final_vt[-1]
                final_vt=[0]+final_vt

                try:
                    final_v=to_categorical(final_vt,110)
                    pre[ma]=to_categorical(pred,110)
                    final[ma]=final_v
                except:
                    pass
                ma+=1
                print(ma)
            
    yield final,pre
      
    print("done")
aio=list(create())

# %%
aio[0][0].shape,aio[0][1].shape,
# Out:
# ((25179, 20, 110), (25179, 20, 110))

# %%
xx=aio[0][0].copy()
yy=aio[0][1].copy()

# %%
import keras
from keras.layers import Reshape,Lambda,Input
import tensorflow as tf
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

n_a=500
n_values=110
Tx=20
reshapor = Reshape((1, n_values))
LSTM_cell = LSTM(n_a, return_state = True)
densor = Dense(n_values, activation='softmax') 


X = Input(shape=(Tx, n_values))
a00 = Input(shape=(n_a,), name='a0')
c00 = Input(shape=(n_a,), name='c0')
a=a00
c=c00
outputs = []
    
for t in range(Tx):
        
        x = Lambda(lambda x: X[:,t,:])(X)
        x = reshapor(x)
        a, _, c = LSTM_cell(inputs=x, initial_state=[a, c])
        out = densor(a)
        outputs.append(out)
        
model = Model(inputs=[X, a00, c00], outputs=outputs)


from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
model.layers[0].output
# Out:
# <tf.Tensor 'input_1:0' shape=(None, 20, 110) dtype=float32>

# %%
from keras.optimizers import Adam

opt = Adam(lr=0.01)# beta_1=0.9, beta_2=0.999, decay=0.01)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
m = 9900
n_a=500
h_s = np.zeros((m, n_a))
c_s = np.zeros((m, n_a))
Y=np.transpose(yy,(1,0,2))
model.fit(x=[xx, h_s, c_s], y=list(Y), epochs=10)
# Out:
# Train on 9900 samples
# Epoch 1/10
# 9900/9900 [==============================] - 15s 2ms/sample - loss: 68.4588 - dense_2_loss: 4.0335 - dense_2_1_loss: 3.7614 - dense_2_2_loss: 3.6197 - dense_2_3_loss: 3.5196 - dense_2_4_loss: 3.4398 - dense_2_5_loss: 3.3807 - dense_2_6_loss: 3.3628 - dense_2_7_loss: 3.3419 - dense_2_8_loss: 3.3281 - dense_2_9_loss: 3.3247 - dense_2_10_loss: 3.3184 - dense_2_11_loss: 3.3289 - dense_2_12_loss: 3.3250 - dense_2_13_loss: 3.3335 - dense_2_14_loss: 3.3234 - dense_2_15_loss: 3.3374 - dense_2_16_loss: 3.3340 - dense_2_17_loss: 3.3322 - dense_2_18_loss: 3.3449 - dense_2_19_loss: 3.3347 - dense_2_accuracy: 0.0362 - dense_2_1_accuracy: 0.0759 - dense_2_2_accuracy: 0.0999 - dense_2_3_accuracy: 0.1141 - dense_2_4_accuracy: 0.1275 - dense_2_5_accuracy: 0.1343 - dense_2_6_accuracy: 0.1422 - dense_2_7_accuracy: 0.1379 - dense_2_8_accuracy: 0.1468 - dense_2_9_accuracy: 0.1469 - dense_2_10_accuracy: 0.1470 - dense_2_11_accuracy: 0.1471 - dense_2_12_accuracy: 0.1451 - dense_2_13_accuracy: 0.1415 - dense_2_14_accuracy: 0.1433 - dense_2_15_accuracy: 0.1395 - dense_2_16_accuracy: 0.1384 - dense_2_17_accuracy: 0.1410 - dense_2_18_accuracy: 0.1385 - dense_2_19_accuracy: 0.1412
# Epoch 2/10
# 9900/9900 [==============================] - 15s 1ms/sample - loss: 50.0082 - dense_2_loss: 3.9659 - dense_2_1_loss: 3.5955 - dense_2_2_loss: 3.2542 - dense_2_3_loss: 2.9612 - dense_2_4_loss: 2.6667 - dense_2_5_loss: 2.5091 - dense_2_6_loss: 2.3864 - dense_2_7_loss: 2.2464 - dense_2_8_loss: 2.2687 - dense_2_9_loss: 2.2168 - dense_2_10_loss: 2.1393 - dense_2_11_loss: 2.2265 - dense_2_12_loss: 2.1930 - dense_2_13_loss: 2.1264 - dense_2_14_loss: 2.2422 - dense_2_15_loss: 2.2120 - dense_2_16_loss: 2.1444 - dense_2_17_loss: 2.2462 - dense_2_18_loss: 2.2268 - dense_2_19_loss: 2.1618 - dense_2_accuracy: 0.0387 - dense_2_1_accuracy: 0.0841 - dense_2_2_accuracy: 0.1614 - dense_2_3_accuracy: 0.2280 - dense_2_4_accuracy: 0.2913 - dense_2_5_accuracy: 0.3287 - dense_2_6_accuracy: 0.3537 - dense_2_7_accuracy: 0.3956 - dense_2_8_accuracy: 0.3815 - dense_2_9_accuracy: 0.4007 - dense_2_10_accuracy: 0.4240 - dense_2_11_accuracy: 0.3959 - dense_2_12_accuracy: 0.3980 - dense_2_13_accuracy: 0.4198 - dense_2_14_accuracy: 0.3926 - dense_2_15_accuracy: 0.4012 - dense_2_16_accuracy: 0.4211 - dense_2_17_accuracy: 0.3886 - dense_2_18_accuracy: 0.3898 - dense_2_19_accuracy: 0.4055
# Epoch 3/10
# 9900/9900 [==============================] - 15s 1ms/sample - loss: 34.4537 - dense_2_loss: 3.9660 - dense_2_1_loss: 3.5946 - dense_2_2_loss: 3.1117 - dense_2_3_loss: 2.5925 - dense_2_4_loss: 2.0698 - dense_2_5_loss: 1.7858 - dense_2_6_loss: 1.5063 - dense_2_7_loss: 1.2896 - dense_2_8_loss: 1.3321 - dense_2_9_loss: 1.2243 - dense_2_10_loss: 1.1135 - dense_2_11_loss: 1.2535 - dense_2_12_loss: 1.1788 - dense_2_13_loss: 1.1080 - dense_2_14_loss: 1.2689 - dense_2_15_loss: 1.2056 - dense_2_16_loss: 1.1129 - dense_2_17_loss: 1.3153 - dense_2_18_loss: 1.2580 - dense_2_19_loss: 1.1564 - dense_2_accuracy: 0.0401 - dense_2_1_accuracy: 0.0835 - dense_2_2_accuracy: 0.1866 - dense_2_3_accuracy: 0.2959 - dense_2_4_accuracy: 0.4269 - dense_2_5_accuracy: 0.5017 - dense_2_6_accuracy: 0.5827 - dense_2_7_accuracy: 0.6504 - dense_2_8_accuracy: 0.6358 - dense_2_9_accuracy: 0.6695 - dense_2_10_accuracy: 0.6976 - dense_2_11_accuracy: 0.6577 - dense_2_12_accuracy: 0.6778 - dense_2_13_accuracy: 0.7013 - dense_2_14_accuracy: 0.6466 - dense_2_15_accuracy: 0.6691 - dense_2_16_accuracy: 0.6982 - dense_2_17_accuracy: 0.6337 - dense_2_18_accuracy: 0.6507 - dense_2_19_accuracy: 0.6738
# Epoch 4/10
# 9900/9900 [==============================] - 15s 1ms/sample - loss: 25.4209 - dense_2_loss: 3.9643 - dense_2_1_loss: 3.5906 - dense_2_2_loss: 3.0204 - dense_2_3_loss: 2.3292 - dense_2_4_loss: 1.6404 - dense_2_5_loss: 1.2621 - dense_2_6_loss: 0.9331 - dense_2_7_loss: 0.7410 - dense_2_8_loss: 0.7516 - dense_2_9_loss: 0.6648 - dense_2_10_loss: 0.5801 - dense_2_11_loss: 0.6844 - dense_2_12_loss: 0.6300 - dense_2_13_loss: 0.5704 - dense_2_14_loss: 0.7317 - dense_2_15_loss: 0.6593 - dense_2_16_loss: 0.5992 - dense_2_17_loss: 0.7502 - dense_2_18_loss: 0.6950 - dense_2_19_loss: 0.6161 - dense_2_accuracy: 0.0369 - dense_2_1_accuracy: 0.0802 - dense_2_2_accuracy: 0.1969 - dense_2_3_accuracy: 0.3562 - dense_2_4_accuracy: 0.5277 - dense_2_5_accuracy: 0.6375 - dense_2_6_accuracy: 0.7454 - dense_2_7_accuracy: 0.8080 - dense_2_8_accuracy: 0.7995 - dense_2_9_accuracy: 0.8295 - dense_2_10_accuracy: 0.8492 - dense_2_11_accuracy: 0.8164 - dense_2_12_accuracy: 0.8333 - dense_2_13_accuracy: 0.8538 - dense_2_14_accuracy: 0.7970 - dense_2_15_accuracy: 0.8216 - dense_2_16_accuracy: 0.8470 - dense_2_17_accuracy: 0.7949 - dense_2_18_accuracy: 0.8130 - dense_2_19_accuracy: 0.8379
# Epoch 5/10
# 9900/9900 [==============================] - 15s 1ms/sample - loss: 20.2588 - dense_2_loss: 3.9613 - dense_2_1_loss: 3.5832 - dense_2_2_loss: 2.9445 - dense_2_3_loss: 2.1276 - dense_2_4_loss: 1.3280 - dense_2_5_loss: 0.9060 - dense_2_6_loss: 0.5984 - dense_2_7_loss: 0.4381 - dense_2_8_loss: 0.4066 - dense_2_9_loss: 0.3685 - dense_2_10_loss: 0.3185 - dense_2_11_loss: 0.3827 - dense_2_12_loss: 0.3428 - dense_2_13_loss: 0.3109 - dense_2_14_loss: 0.4015 - dense_2_15_loss: 0.3677 - dense_2_16_loss: 0.3175 - dense_2_17_loss: 0.4318 - dense_2_18_loss: 0.3723 - dense_2_19_loss: 0.3500 - dense_2_accuracy: 0.0375 - dense_2_1_accuracy: 0.0834 - dense_2_2_accuracy: 0.2148 - dense_2_3_accuracy: 0.4060 - dense_2_4_accuracy: 0.6153 - dense_2_5_accuracy: 0.7430 - dense_2_6_accuracy: 0.8406 - dense_2_7_accuracy: 0.8932 - dense_2_8_accuracy: 0.9032 - dense_2_9_accuracy: 0.9103 - dense_2_10_accuracy: 0.9229 - dense_2_11_accuracy: 0.9068 - dense_2_12_accuracy: 0.9166 - dense_2_13_accuracy: 0.9293 - dense_2_14_accuracy: 0.8980 - dense_2_15_accuracy: 0.9074 - dense_2_16_accuracy: 0.9248 - dense_2_17_accuracy: 0.8852 - dense_2_18_accuracy: 0.9056 - dense_2_19_accuracy: 0.9164
# Epoch 6/10
# 9900/9900 [==============================] - 15s 1ms/sample - loss: 17.4567 - dense_2_loss: 3.9620 - dense_2_1_loss: 3.5786 - dense_2_2_loss: 2.8887 - dense_2_3_loss: 1.9387 - dense_2_4_loss: 1.0539 - dense_2_5_loss: 0.6288 - dense_2_6_loss: 0.4036 - dense_2_7_loss: 0.2779 - dense_2_8_loss: 0.2552 - dense_2_9_loss: 0.2260 - dense_2_10_loss: 0.1963 - dense_2_11_loss: 0.2325 - dense_2_12_loss: 0.2149 - dense_2_13_loss: 0.1916 - dense_2_14_loss: 0.2434 - dense_2_15_loss: 0.2276 - dense_2_16_loss: 0.1981 - dense_2_17_loss: 0.2690 - dense_2_18_loss: 0.2474 - dense_2_19_loss: 0.2193 - dense_2_accuracy: 0.0384 - dense_2_1_accuracy: 0.0877 - dense_2_2_accuracy: 0.2230 - dense_2_3_accuracy: 0.4498 - dense_2_4_accuracy: 0.6935 - dense_2_5_accuracy: 0.8265 - dense_2_6_accuracy: 0.8985 - dense_2_7_accuracy: 0.9382 - dense_2_8_accuracy: 0.9420 - dense_2_9_accuracy: 0.9497 - dense_2_10_accuracy: 0.9606 - dense_2_11_accuracy: 0.9469 - dense_2_12_accuracy: 0.9539 - dense_2_13_accuracy: 0.9582 - dense_2_14_accuracy: 0.9431 - dense_2_15_accuracy: 0.9468 - dense_2_16_accuracy: 0.9548 - dense_2_17_accuracy: 0.9348 - dense_2_18_accuracy: 0.9388 - dense_2_19_accuracy: 0.9503
# Epoch 7/10
# 9900/9900 [==============================] - 15s 1ms/sample - loss: 16.0622 - dense_2_loss: 3.9604 - dense_2_1_loss: 3.5718 - dense_2_2_loss: 2.8292 - dense_2_3_loss: 1.7506 - dense_2_4_loss: 0.8469 - dense_2_5_loss: 0.4712 - dense_2_6_loss: 0.2917 - dense_2_7_loss: 0.2210 - dense_2_8_loss: 0.2008 - dense_2_9_loss: 0.1803 - dense_2_10_loss: 0.1542 - dense_2_11_loss: 0.1762 - dense_2_12_loss: 0.1671 - dense_2_13_loss: 0.1456 - dense_2_14_loss: 0.1921 - dense_2_15_loss: 0.1705 - dense_2_16_loss: 0.1579 - dense_2_17_loss: 0.2120 - dense_2_18_loss: 0.1911 - dense_2_19_loss: 0.1666 - dense_2_accuracy: 0.0376 - dense_2_1_accuracy: 0.0843 - dense_2_2_accuracy: 0.2365 - dense_2_3_accuracy: 0.4943 - dense_2_4_accuracy: 0.7601 - dense_2_5_accuracy: 0.8761 - dense_2_6_accuracy: 0.9311 - dense_2_7_accuracy: 0.9505 - dense_2_8_accuracy: 0.9564 - dense_2_9_accuracy: 0.9600 - dense_2_10_accuracy: 0.9663 - dense_2_11_accuracy: 0.9614 - dense_2_12_accuracy: 0.9634 - dense_2_13_accuracy: 0.9678 - dense_2_14_accuracy: 0.9576 - dense_2_15_accuracy: 0.9606 - dense_2_16_accuracy: 0.9667 - dense_2_17_accuracy: 0.9488 - dense_2_18_accuracy: 0.9576 - dense_2_19_accuracy: 0.9637
# Epoch 8/10
# 9900/9900 [==============================] - 15s 1ms/sample - loss: 15.1472 - dense_2_loss: 3.9590 - dense_2_1_loss: 3.5700 - dense_2_2_loss: 2.7785 - dense_2_3_loss: 1.5838 - dense_2_4_loss: 0.7017 - dense_2_5_loss: 0.3736 - dense_2_6_loss: 0.2427 - dense_2_7_loss: 0.1778 - dense_2_8_loss: 0.1690 - dense_2_9_loss: 0.1491 - dense_2_10_loss: 0.1315 - dense_2_11_loss: 0.1564 - dense_2_12_loss: 0.1382 - dense_2_13_loss: 0.1244 - dense_2_14_loss: 0.1553 - dense_2_15_loss: 0.1411 - dense_2_16_loss: 0.1302 - dense_2_17_loss: 0.1628 - dense_2_18_loss: 0.1613 - dense_2_19_loss: 0.1417 - dense_2_accuracy: 0.0399 - dense_2_1_accuracy: 0.0867 - dense_2_2_accuracy: 0.2398 - dense_2_3_accuracy: 0.5334 - dense_2_4_accuracy: 0.8069 - dense_2_5_accuracy: 0.9094 - dense_2_6_accuracy: 0.9438 - dense_2_7_accuracy: 0.9602 - dense_2_8_accuracy: 0.9613 - dense_2_9_accuracy: 0.9657 - dense_2_10_accuracy: 0.9706 - dense_2_11_accuracy: 0.9645 - dense_2_12_accuracy: 0.9688 - dense_2_13_accuracy: 0.9719 - dense_2_14_accuracy: 0.9632 - dense_2_15_accuracy: 0.9683 - dense_2_16_accuracy: 0.9724 - dense_2_17_accuracy: 0.9599 - dense_2_18_accuracy: 0.9639 - dense_2_19_accuracy: 0.9698
# Epoch 9/10
# 9900/9900 [==============================] - 15s 1ms/sample - loss: 14.7841 - dense_2_loss: 3.9593 - dense_2_1_loss: 3.5612 - dense_2_2_loss: 2.7229 - dense_2_3_loss: 1.4621 - dense_2_4_loss: 0.6211 - dense_2_5_loss: 0.3502 - dense_2_6_loss: 0.2329 - dense_2_7_loss: 0.1631 - dense_2_8_loss: 0.1595 - dense_2_9_loss: 0.1420 - dense_2_10_loss: 0.1314 - dense_2_11_loss: 0.1415 - dense_2_12_loss: 0.1353 - dense_2_13_loss: 0.1184 - dense_2_14_loss: 0.1559 - dense_2_15_loss: 0.1369 - dense_2_16_loss: 0.1295 - dense_2_17_loss: 0.1667 - dense_2_18_loss: 0.1560 - dense_2_19_loss: 0.1418 - dense_2_accuracy: 0.0377 - dense_2_1_accuracy: 0.0868 - dense_2_2_accuracy: 0.2470 - dense_2_3_accuracy: 0.5687 - dense_2_4_accuracy: 0.8295 - dense_2_5_accuracy: 0.9152 - dense_2_6_accuracy: 0.9463 - dense_2_7_accuracy: 0.9605 - dense_2_8_accuracy: 0.9630 - dense_2_9_accuracy: 0.9697 - dense_2_10_accuracy: 0.9708 - dense_2_11_accuracy: 0.9686 - dense_2_12_accuracy: 0.9694 - dense_2_13_accuracy: 0.9728 - dense_2_14_accuracy: 0.9636 - dense_2_15_accuracy: 0.9671 - dense_2_16_accuracy: 0.9699 - dense_2_17_accuracy: 0.9586 - dense_2_18_accuracy: 0.9634 - dense_2_19_accuracy: 0.9652
# Epoch 10/10
# 9900/9900 [==============================] - 15s 1ms/sample - loss: 14.6160 - dense_2_loss: 3.9588 - dense_2_1_loss: 3.5601 - dense_2_2_loss: 2.6879 - dense_2_3_loss: 1.3730 - dense_2_4_loss: 0.5659 - dense_2_5_loss: 0.3213 - dense_2_6_loss: 0.2226 - dense_2_7_loss: 0.1747 - dense_2_8_loss: 0.1666 - dense_2_9_loss: 0.1466 - dense_2_10_loss: 0.1338 - dense_2_11_loss: 0.1496 - dense_2_12_loss: 0.1363 - dense_2_13_loss: 0.1262 - dense_2_14_loss: 0.1545 - dense_2_15_loss: 0.1411 - dense_2_16_loss: 0.1306 - dense_2_17_loss: 0.1736 - dense_2_18_loss: 0.1543 - dense_2_19_loss: 0.1386 - dense_2_accuracy: 0.0373 - dense_2_1_accuracy: 0.0875 - dense_2_2_accuracy: 0.2538 - dense_2_3_accuracy: 0.5905 - dense_2_4_accuracy: 0.8487 - dense_2_5_accuracy: 0.9188 - dense_2_6_accuracy: 0.9458 - dense_2_7_accuracy: 0.9592 - dense_2_8_accuracy: 0.9608 - dense_2_9_accuracy: 0.9676 - dense_2_10_accuracy: 0.9704 - dense_2_11_accuracy: 0.9627 - dense_2_12_accuracy: 0.9684 - dense_2_13_accuracy: 0.9707 - dense_2_14_accuracy: 0.9626 - dense_2_15_accuracy: 0.9673 - dense_2_16_accuracy: 0.9690 - dense_2_17_accuracy: 0.9570 - dense_2_18_accuracy: 0.9619 - dense_2_19_accuracy: 0.9665

# %%
from keras.layers import RepeatVector
def one_hot(x):
  x = keras.backend.argmax(x)
  # x=tf.random.categorical(x,1,dtype=tf.int64)
  x = tf.one_hot(indices=x, depth=110)
  x = RepeatVector(1)(x)
  return x
x_test = Input(shape=(1, n_values))
a_test = Input(shape=(n_a,), name='a0')
c_test = Input(shape=(n_a,), name='c0')
at = a_test
ct = c_test
xt= x_test
Ty=80

outputs2 = []

for t in range(Ty):
    
    at, _, ct = LSTM_cell(inputs=xt, initial_state=[at, ct])
    
    out = densor(at)

    outputs2.append(out)
    

    xt = Lambda(lambda x: one_hot(x))(out)
    
inference_model = Model(inputs=[x_test,a_test,c_test],outputs=outputs2)

# %%
x_initializer = np.zeros((1, 1, 110))
a_initializer = np.zeros((1, n_a))
c_initializer = np.zeros((1, n_a))
pred = inference_model.predict([x_initializer, a_initializer, c_initializer])
indices = np.argmax(np.array(pred),axis=-1)
indices.ravel()
# Out:
# array([70, 58, 74, 54, 78, 58, 74, 42, 75, 59, 71, 54, 75, 59, 71, 81, 54,
#        83, 59, 80, 54, 59, 83, 80, 42, 77, 59, 80, 54, 59, 77, 80, 54, 85,
#        59, 81, 54, 77, 59, 85, 81, 42, 82, 58, 81, 54, 82, 58, 77, 54, 78,
#        58, 77, 54, 78, 58, 72, 54, 73, 58, 72, 54, 73, 58, 69, 54, 70, 58,
#        69, 70, 54, 58, 65, 54, 66, 58, 65, 54, 66, 58])

# %%
midi_pretty_format=pretty_midi.PrettyMIDI()
cello = pretty_midi.Instrument(program=2)
time = 0
step = 0.3
for note_number in indices.ravel():

    myNote = pretty_midi.Note(velocity=100, pitch=note_number, start=time, end=time+step)
    cello.notes.append(myNote)
    time += step
midi_pretty_format.instruments.append(cello)
midi_pretty_format.write('cell.midi')

import IPython
audio_data = midi_pretty_format.synthesize()
IPython.display.Audio(audio_data, rate=44100)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
